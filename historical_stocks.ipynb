# %%
# convertire il notebook in uno script python
# !jupyter nbconvert --to script Data.ipynb

# %%
import pandas as pd
import numpy as np

# %%
dataStocks = pd.read_csv("dataset/historical_stocks.csv")

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
dataStocks.nunique()
# Out:
# ticker      6460
# exchange       2
# name        5462
# sector        13
# industry     136
# dtype: int64

# %%
dataStocks.isnull().sum()
# Out:
# ticker         0
# exchange       0
# name           0
# sector      1440
# industry    1440
# dtype: int64

# %%
dataStocks.groupby('name').count()
# Out:
#                                         ticker  exchange  sector  industry
# name
# 1-800 FLOWERS.COM, INC.                      1         1       1         1
# 1347 PROPERTY INSURANCE HOLDINGS, INC.       2         2       2         2
# 180 DEGREE CAPITAL CORP.                     1         1       1         1
# 1ST CONSTITUTION BANCORP (NJ)                1         1       1         1
# 1ST SOURCE CORPORATION                       1         1       1         1
# ...                                        ...       ...     ...       ...
# ZUMIEZ INC.                                  1         1       1         1
# ZUORA, INC.                                  1         1       1         1
# ZYMEWORKS INC.                               1         1       1         1
# ZYNERBA PHARMACEUTICALS, INC.                1         1       1         1
# ZYNGA INC.                                   1         1       1         1
#
# [5462 rows x 4 columns]

# %%
dataStocks[dataStocks.name == 'GASLOG LP.']
# Out:
#       ticker exchange        name             sector               industry
# 4561    GLOG     NYSE  GASLOG LP.  CONSUMER SERVICES  MARINE TRANSPORTATION
# 4562  GLOG^A     NYSE  GASLOG LP.                NaN                    NaN

# %%
app = dataStocks.groupby('name').count()[['ticker', 'sector']]
app
# Out:
#                                         ticker  sector
# name
# 1-800 FLOWERS.COM, INC.                      1       1
# 1347 PROPERTY INSURANCE HOLDINGS, INC.       2       2
# 180 DEGREE CAPITAL CORP.                     1       1
# 1ST CONSTITUTION BANCORP (NJ)                1       1
# 1ST SOURCE CORPORATION                       1       1
# ...                                        ...     ...
# ZUMIEZ INC.                                  1       1
# ZUORA, INC.                                  1       1
# ZYMEWORKS INC.                               1       1
# ZYNERBA PHARMACEUTICALS, INC.                1       1
# ZYNGA INC.                                   1       1
#
# [5462 rows x 2 columns]

# %%
# il numero di volte che l'azienda compare (determinato da ticker) è diverso dal numero dei nomi dati al settore.
# Questo significa che l'azienda per sbaglio non ha messo sempre il nome del settore. Prendo le aziende che non
# hanno messo sempre il nome al settore
app2 = app.loc[app.ticker != app.sector]
# prendo le aziende che hanno messo almeno un nome nel settore (le aziende con non l'hanno mai messo vanno buttate)
app3 = app2.loc[app2.sector != 0]
# lista delle aziende che si sono scordate di mettere il nome del settore, ma che l'hanno messo almeno una volta
lista_aziende_con_NaN = list(app3.index)

# %%
# set delle aziende che si sono scordate di mettere il nome del settore, ma l'hanno messo almeno una volta
set_aziende_con_NaN = set(lista_aziende_con_NaN)
set_aziende_con_NaN
# Out:
# {'AEGON NV',
#  'ALEXANDRIA REAL ESTATE EQUITIES, INC.',
#  'ALLSTATE CORPORATION (THE)',
#  'ALLY FINANCIAL INC.',
#  'AMERICAN HOMES 4 RENT',
#  'AMERICAN INTERNATIONAL GROUP, INC.',
#  'AMTRUST FINANCIAL SERVICES, INC.',
#  'ANNALY CAPITAL MANAGEMENT INC',
#  'ANWORTH MORTGAGE ASSET  CORPORATION',
#  'APARTMENT INVESTMENT AND MANAGEMENT COMPANY',
#  'APOLLO COMMERCIAL REAL ESTATE FINANCE',
#  'APOLLO GLOBAL MANAGEMENT, LLC',
#  'ARBOR REALTY TRUST',
#  'ARES MANAGEMENT L.P.',
#  'ARLINGTON ASSET INVESTMENT CORP',
#  'ARMOUR RESIDENTIAL REIT, INC.',
#  'ASHFORD HOSPITALITY TRUST INC',
#  'ASPEN INSURANCE HOLDINGS LIMITED',
#  'ASSOCIATED BANC-CORP',
#  'ASSURED GUARANTY LTD.',
#  'AXIS CAPITAL HOLDINGS LIMITED',
#  'BANC OF CALIFORNIA, INC.',
#  'BANCO SANTANDER, S.A.',
#  'BANK OF AMERICA CORPORATION',
#  'BANK OF NEW YORK MELLON CORPORATION (THE)',
#  'BARCLAYS PLC',
#  'BB&T CORPORATION',
#  'BELDEN INC',
#  'BIGLARI HOLDINGS INC.',
#  'BIO-RAD LABORATORIES, INC.',
#  'BOSTON PROPERTIES, INC.',
#  'BRAEMAR HOTELS & RESORTS INC.',
#  'CAI INTERNATIONAL, INC.',
#  'CAPITAL ONE FINANCIAL CORPORATION',
#  'CAPITOL INVESTMENT CORP. IV',
#  'CAPSTEAD MORTGAGE CORPORATION',
#  'CBL & ASSOCIATES PROPERTIES, INC.',
#  'CEDAR REALTY TRUST, INC.',
#  'CENTRAIS ELECTRICAS BRASILEIRAS S.A.- ELETROBRAS',
#  'CHERRY HILL MORTGAGE INVESTMENT CORPORATION',
#  'CHESAPEAKE ENERGY CORPORATION',
#  'CHIMERA INVESTMENT CORPORATION',
#  'CINCINNATI BELL INC',
#  'CITIGROUP INC.',
#  'CITY OFFICE REIT, INC.',
#  'COLONY NORTHSTAR, INC.',
#  'COMERICA INCORPORATED',
#  'COMP EN DE MN CEMIG ADS',
#  'COMPASS DIVERSIFIED HOLDINGS',
#  'CONSTELLATION BRANDS INC',
#  'CORENERGY INFRASTRUCTURE TRUST, INC.',
#  'COSTAMARE INC.',
#  'CROWN CASTLE INTERNATIONAL CORPORATION',
#  'CULLEN/FROST BANKERS, INC.',
#  'CUSTOMERS BANCORP, INC',
#  'CYS INVESTMENTS, INC.',
#  'DDR CORP.',
#  'DIANA SHIPPING INC.',
#  'DIGITAL REALTY TRUST, INC.',
#  'DRIVE SHACK INC.',
#  'DYNAGAS LNG PARTNERS LP',
#  'DYNEX CAPITAL, INC.',
#  'EASTMAN KODAK COMPANY',
#  'EATON VANCE CORPORATION',
#  'ENERGY TRANSFER PARTNERS, L.P.',
#  'EPR PROPERTIES',
#  'EQUITY COMMONWEALTH',
#  'F.N.B. CORPORATION',
#  'FARMLAND PARTNERS INC.',
#  'FEDERAL AGRICULTURAL MORTGAGE CORPORATION',
#  'FEDERAL REALTY INVESTMENT TRUST',
#  'FGL HOLDINGS',
#  'FIRST HORIZON NATIONAL CORPORATION',
#  'FIVE OAKS INVESTMENT CORP.',
#  'GASLOG LP.',
#  'GASLOG PARTNERS LP',
#  'GENERAL MOTORS COMPANY',
#  'GENIE ENERGY LTD.',
#  'GIGCAPITAL, INC.',
#  'GLOBAL MEDICAL REIT INC.',
#  'GLOBAL NET LEASE, INC.',
#  'GLOBAL SHIP LEASE, INC.',
#  'GOLDMAN SACHS GROUP, INC. (THE)',
#  'GRAY TELEVISION, INC.',
#  'HALCON RESOURCES CORPORATION',
#  'HARTFORD FINANCIAL SERVICES GROUP, INC. (THE)',
#  'HAVERTY FURNITURE COMPANIES, INC.',
#  'HAWAIIAN ELECTRIC INDUSTRIES, INC.',
#  'HEICO CORPORATION',
#  'HERSHA HOSPITALITY TRUST',
#  'HESS CORPORATION',
#  'HOEGH LNG PARTNERS LP',
#  'HSBC HOLDINGS PLC',
#  'HUDBAY MINERALS INC.',
#  'INNOVATIVE INDUSTRIAL PROPERTIES, INC.',
#  'INVESCO MORTGAGE CAPITAL INC',
#  'INVESTORS REAL ESTATE TRUST',
#  'ISTAR FINANCIAL INC.',
#  'J P MORGAN CHASE & CO',
#  'JERNIGAN CAPITAL, INC.',
#  'JUST ENERGY GROUP, INC.',
#  'KEYCORP',
#  'KIMCO REALTY CORPORATION',
#  'KINDER MORGAN, INC.',
#  'KKR & CO. L.P.',
#  'LASALLE HOTEL PROPERTIES',
#  'LEGACY ACQUISITION CORP.',
#  'LEO HOLDINGS CORP.',
#  'LINCOLN NATIONAL CORPORATION',
#  'M I ACQUISITIONS, INC.',
#  'M&T BANK CORPORATION',
#  'MAIDEN HOLDINGS, LTD.',
#  'MECHEL PAO',
#  'METLIFE, INC.',
#  'MFA FINANCIAL, INC.',
#  'MID-AMERICA APARTMENT COMMUNITIES, INC.',
#  'MOLSON COORS BREWING  COMPANY',
#  'MONMOUTH REAL ESTATE INVESTMENT CORPORATION',
#  'MORGAN STANLEY',
#  'MOSAIC ACQUISITION CORP.',
#  'NATIONAL RETAIL PROPERTIES',
#  'NATIONAL STORAGE AFFILIATES TRUST',
#  'NAVIOS MARITIME HOLDINGS INC.',
#  'NEW YORK COMMUNITY BANCORP, INC.',
#  'NEXTERA ENERGY, INC.',
#  'NGL ENERGY PARTNERS LP',
#  'NRG YIELD, INC.',
#  'NUSTAR ENERGY L.P.',
#  'OFG BANCORP',
#  'ONE MADISON CORPORATION',
#  'PEBBLEBROOK HOTEL TRUST',
#  'PENNSYLVANIA REAL ESTATE INVESTMENT TRUST',
#  'PENNYMAC MORTGAGE INVESTMENT TRUST',
#  'PETROLEO BRASILEIRO S.A.- PETROBRAS',
#  'PITNEY BOWES INC.',
#  'PNC FINANCIAL SERVICES GROUP, INC. (THE)',
#  'PRUDENTIAL PUBLIC LIMITED COMPANY',
#  'PS BUSINESS PARKS, INC.',
#  'PUBLIC STORAGE',
#  'QTS REALTY TRUST, INC.',
#  'RAIT FINANCIAL TRUST',
#  'RAMCO-GERSHENSON PROPERTIES TRUST',
#  'RAYONIER ADVANCED MATERIALS INC.',
#  'REGALWOOD GLOBAL ENERGY LTD.',
#  'REGIONS FINANCIAL CORPORATION',
#  'RENAISSANCERE HOLDINGS LTD.',
#  'RESOURCE CAPITAL CORP.',
#  'REXFORD INDUSTRIAL REALTY, INC.',
#  'REXNORD CORPORATION',
#  'RLJ LODGING TRUST',
#  'ROYAL BANK OF CANADA',
#  'ROYAL BANK SCOTLAND PLC (THE)',
#  'SAFE BULKERS, INC',
#  'SAUL CENTERS, INC.',
#  'SEASPAN CORPORATION',
#  'SERITAGE GROWTH PROPERTIES',
#  'SIMON PROPERTY GROUP, INC.',
#  'SL GREEN REALTY CORPORATION',
#  'SOCIAL CAPITAL HEDOSOPHIA HOLDINGS CORP.',
#  'SPIRIT REALTY CAPITAL, INC.',
#  'STAG INDUSTRIAL, INC.',
#  'STATE STREET CORPORATION',
#  'STEEL PARTNERS HOLDINGS LP',
#  'SUMMIT HOTEL PROPERTIES, INC.',
#  'SUNSTONE HOTEL INVESTORS, INC.',
#  'SUNTRUST BANKS, INC.',
#  'SYNOVUS FINANCIAL CORP.',
#  'SYNTHETIC FIXED-INCOME SECURITIES, INC.',
#  'TAUBMAN CENTERS, INC.',
#  'TCF FINANCIAL CORPORATION',
#  'TEEKAY LNG PARTNERS L.P.',
#  'TEEKAY OFFSHORE PARTNERS L.P.',
#  'TELECOM ITALIA S.P.A.',
#  'THE CHARLES SCHWAB CORPORATION',
#  'TIDEWATER INC.',
#  'TORCHMARK CORPORATION',
#  'TPG PACE ENERGY HOLDINGS CORP.',
#  'TPG PACE HOLDINGS CORP.',
#  'TRI CONTINENTAL CORPORATION',
#  'TSAKOS ENERGY NAVIGATION LTD',
#  'TWO HARBORS INVESTMENTS CORP',
#  'U.S. BANCORP',
#  'UMH PROPERTIES, INC.',
#  'UNION ACQUISITION CORP.',
#  'URSTADT BIDDLE PROPERTIES INC.',
#  'VALIDUS HOLDINGS, LTD.',
#  'VALLEY NATIONAL BANCORP',
#  'VEREIT INC.',
#  'VISTRA ENERGY CORP.',
#  'VORNADO REALTY TRUST',
#  'W.R. BERKLEY CORPORATION',
#  'WASHINGTON PRIME GROUP INC.',
#  'WATSCO, INC.',
#  'WEBSTER FINANCIAL CORPORATION',
#  'WELLS FARGO & COMPANY',
#  'WELLTOWER INC.',
#  'ZIONS BANCORPORATION'}

# %%
diz = {}
for index, row in dataStocks.iterrows():
    # se il nome dell'azienda si trova tra quelle che non hanno assegnato tutti i nomi a sector e industry
    if row['name'] in set_aziende_con_NaN:
        # e se tutti i valori della riga non sono nulli (quindi ho l'azienda pippo che compare 5 volte e 1 
        # volta mette tutti i valori giusti, io devo vedere in quale riga mette tutti quei valori giusti, 
        # in modo da prendere le informazioni) 
        # (un po' brutto farlo così)
        # inoltre se l'azienda pippo compare 5 volte e 2 volte mette tutti i volori giusti, entrembe le volte questi
        # vengono messi nel dizionario, penso che è come se c'è una sovrascrittura tutte le volte e non
        # è un problema perché i valori sono sempre uguali
        if not row.isnull().values.any():
            # print("Nome:   " + row['name'] + "  ", "Settore: " + row['sector'], "Industria:   " + row['industry'])
            # alla chiave nome dell'azienda, associo la lista di valori corretti
            diz[row['name']] = [row['sector'], row['industry']]

# %%
diz
# Out:
# {'AMTRUST FINANCIAL SERVICES, INC.': ['FINANCE', 'PROPERTY-CASUALTY INSURERS'],
#  'BARCLAYS PLC': ['FINANCE', 'COMMERCIAL BANKS'],
#  'M I ACQUISITIONS, INC.': ['FINANCE', 'BUSINESS SERVICES'],
#  'MAIDEN HOLDINGS, LTD.': ['FINANCE', 'PROPERTY-CASUALTY INSURERS'],
#  'ZIONS BANCORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'AEGON NV': ['FINANCE', 'LIFE INSURANCE'],
#  'ALEXANDRIA REAL ESTATE EQUITIES, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'ALLSTATE CORPORATION (THE)': ['FINANCE', 'PROPERTY-CASUALTY INSURERS'],
#  'ALLY FINANCIAL INC.': ['FINANCE', 'FINANCE: CONSUMER SERVICES'],
#  'AMERICAN HOMES 4 RENT': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'AMERICAN INTERNATIONAL GROUP, INC.': ['FINANCE',
#   'PROPERTY-CASUALTY INSURERS'],
#  'ANNALY CAPITAL MANAGEMENT INC': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'ANWORTH MORTGAGE ASSET  CORPORATION': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'APARTMENT INVESTMENT AND MANAGEMENT COMPANY': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'APOLLO COMMERCIAL REAL ESTATE FINANCE': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'APOLLO GLOBAL MANAGEMENT, LLC': ['FINANCE', 'INVESTMENT MANAGERS'],
#  'ARBOR REALTY TRUST': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'ARES MANAGEMENT L.P.': ['FINANCE', 'INVESTMENT MANAGERS'],
#  'ARLINGTON ASSET INVESTMENT CORP': ['FINANCE', 'FINANCE/INVESTORS SERVICES'],
#  'ARMOUR RESIDENTIAL REIT, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'ASHFORD HOSPITALITY TRUST INC': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'ASPEN INSURANCE HOLDINGS LIMITED': ['FINANCE', 'PROPERTY-CASUALTY INSURERS'],
#  'ASSOCIATED BANC-CORP': ['FINANCE', 'MAJOR BANKS'],
#  'ASSURED GUARANTY LTD.': ['FINANCE', 'PROPERTY-CASUALTY INSURERS'],
#  'AXIS CAPITAL HOLDINGS LIMITED': ['FINANCE', 'PROPERTY-CASUALTY INSURERS'],
#  'BANC OF CALIFORNIA, INC.': ['FINANCE', 'MAJOR BANKS'],
#  'BANCO SANTANDER, S.A.': ['FINANCE', 'COMMERCIAL BANKS'],
#  'BANK OF AMERICA CORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'BANK OF NEW YORK MELLON CORPORATION (THE)': ['FINANCE', 'MAJOR BANKS'],
#  'BB&T CORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'BELDEN INC': ['BASIC INDUSTRIES', 'TELECOMMUNICATIONS EQUIPMENT'],
#  'BIGLARI HOLDINGS INC.': ['CONSUMER SERVICES', 'RESTAURANTS'],
#  'BIO-RAD LABORATORIES, INC.': ['CAPITAL GOODS',
#   'BIOTECHNOLOGY: LABORATORY ANALYTICAL INSTRUMENTS'],
#  'BOSTON PROPERTIES, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'BRAEMAR HOTELS & RESORTS INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'CAI INTERNATIONAL, INC.': ['TECHNOLOGY', 'DIVERSIFIED COMMERCIAL SERVICES'],
#  'CAPITAL ONE FINANCIAL CORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'CAPITOL INVESTMENT CORP. IV': ['FINANCE', 'BUSINESS SERVICES'],
#  'CAPSTEAD MORTGAGE CORPORATION': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'CBL & ASSOCIATES PROPERTIES, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'CEDAR REALTY TRUST, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'CENTRAIS ELECTRICAS BRASILEIRAS S.A.- ELETROBRAS': ['PUBLIC UTILITIES',
#   'ELECTRIC UTILITIES: CENTRAL'],
#  'CHERRY HILL MORTGAGE INVESTMENT CORPORATION': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'CHESAPEAKE ENERGY CORPORATION': ['ENERGY', 'OIL & GAS PRODUCTION'],
#  'CHIMERA INVESTMENT CORPORATION': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'CINCINNATI BELL INC': ['PUBLIC UTILITIES', 'TELECOMMUNICATIONS EQUIPMENT'],
#  'CITIGROUP INC.': ['FINANCE', 'MAJOR BANKS'],
#  'CITY OFFICE REIT, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'COLONY NORTHSTAR, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'COMERICA INCORPORATED': ['FINANCE', 'MAJOR BANKS'],
#  'COMP EN DE MN CEMIG ADS': ['PUBLIC UTILITIES',
#   'ELECTRIC UTILITIES: CENTRAL'],
#  'COMPASS DIVERSIFIED HOLDINGS': ['CONSUMER DURABLES', 'HOME FURNISHINGS'],
#  'CONSTELLATION BRANDS INC': ['CONSUMER NON-DURABLES',
#   'BEVERAGES (PRODUCTION/DISTRIBUTION)'],
#  'KEYCORP': ['FINANCE', 'MAJOR BANKS'],
#  'CORENERGY INFRASTRUCTURE TRUST, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'COSTAMARE INC.': ['TRANSPORTATION', 'MARINE TRANSPORTATION'],
#  'CROWN CASTLE INTERNATIONAL CORPORATION': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'CULLEN/FROST BANKERS, INC.': ['FINANCE', 'MAJOR BANKS'],
#  'CUSTOMERS BANCORP, INC': ['FINANCE', 'MAJOR BANKS'],
#  'CYS INVESTMENTS, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'DDR CORP.': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'DIANA SHIPPING INC.': ['TRANSPORTATION', 'MARINE TRANSPORTATION'],
#  'DIGITAL REALTY TRUST, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'DRIVE SHACK INC.': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'DYNAGAS LNG PARTNERS LP': ['CONSUMER SERVICES', 'MARINE TRANSPORTATION'],
#  'DYNEX CAPITAL, INC.': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'EASTMAN KODAK COMPANY': ['MISCELLANEOUS', 'INDUSTRIAL MACHINERY/COMPONENTS'],
#  'EATON VANCE CORPORATION': ['FINANCE', 'INVESTMENT MANAGERS'],
#  'ENERGY TRANSFER PARTNERS, L.P.': ['ENERGY', 'NATURAL GAS DISTRIBUTION'],
#  'EPR PROPERTIES': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'EQUITY COMMONWEALTH': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'F.N.B. CORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'FARMLAND PARTNERS INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'FEDERAL AGRICULTURAL MORTGAGE CORPORATION': ['FINANCE', 'FINANCE COMPANIES'],
#  'FEDERAL REALTY INVESTMENT TRUST': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'FGL HOLDINGS': ['FINANCE', 'LIFE INSURANCE'],
#  'FIRST HORIZON NATIONAL CORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'FIVE OAKS INVESTMENT CORP.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'GASLOG LP.': ['CONSUMER SERVICES', 'MARINE TRANSPORTATION'],
#  'GASLOG PARTNERS LP': ['CONSUMER SERVICES', 'MARINE TRANSPORTATION'],
#  'GENERAL MOTORS COMPANY': ['CAPITAL GOODS', 'AUTO MANUFACTURING'],
#  'GENIE ENERGY LTD.': ['PUBLIC UTILITIES', 'POWER GENERATION'],
#  'GIGCAPITAL, INC.': ['FINANCE', 'BUSINESS SERVICES'],
#  'GLOBAL MEDICAL REIT INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'GLOBAL NET LEASE, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'GLOBAL SHIP LEASE, INC.': ['TRANSPORTATION', 'MARINE TRANSPORTATION'],
#  'GOLDMAN SACHS GROUP, INC. (THE)': ['FINANCE',
#   'INVESTMENT BANKERS/BROKERS/SERVICE'],
#  'GRAY TELEVISION, INC.': ['CONSUMER SERVICES', 'BROADCASTING'],
#  'HALCON RESOURCES CORPORATION': ['ENERGY', 'OIL & GAS PRODUCTION'],
#  'HARTFORD FINANCIAL SERVICES GROUP, INC. (THE)': ['FINANCE',
#   'PROPERTY-CASUALTY INSURERS'],
#  'HAVERTY FURNITURE COMPANIES, INC.': ['CONSUMER SERVICES',
#   'OTHER SPECIALTY STORES'],
#  'HAWAIIAN ELECTRIC INDUSTRIES, INC.': ['PUBLIC UTILITIES',
#   'ELECTRIC UTILITIES: CENTRAL'],
#  'HEICO CORPORATION': ['CAPITAL GOODS', 'AEROSPACE'],
#  'HERSHA HOSPITALITY TRUST': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'HESS CORPORATION': ['ENERGY', 'INTEGRATED OIL COMPANIES'],
#  'HOEGH LNG PARTNERS LP': ['CONSUMER SERVICES', 'MARINE TRANSPORTATION'],
#  'HSBC HOLDINGS PLC': ['FINANCE', 'SAVINGS INSTITUTIONS'],
#  'HUDBAY MINERALS INC.': ['BASIC INDUSTRIES', 'PRECIOUS METALS'],
#  'INNOVATIVE INDUSTRIAL PROPERTIES, INC.': ['FINANCE', 'REAL ESTATE'],
#  'INVESCO MORTGAGE CAPITAL INC': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'INVESTORS REAL ESTATE TRUST': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'ISTAR FINANCIAL INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'J P MORGAN CHASE & CO': ['FINANCE', 'MAJOR BANKS'],
#  'JERNIGAN CAPITAL, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'JUST ENERGY GROUP, INC.': ['PUBLIC UTILITIES', 'OIL/GAS TRANSMISSION'],
#  'KIMCO REALTY CORPORATION': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'KINDER MORGAN, INC.': ['PUBLIC UTILITIES', 'NATURAL GAS DISTRIBUTION'],
#  'KKR & CO. L.P.': ['FINANCE', 'INVESTMENT MANAGERS'],
#  'LASALLE HOTEL PROPERTIES': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'LEGACY ACQUISITION CORP.': ['FINANCE', 'BUSINESS SERVICES'],
#  'LEO HOLDINGS CORP.': ['FINANCE', 'BUSINESS SERVICES'],
#  'LINCOLN NATIONAL CORPORATION': ['FINANCE', 'LIFE INSURANCE'],
#  'M&T BANK CORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'MECHEL PAO': ['BASIC INDUSTRIES', 'STEEL/IRON ORE'],
#  'METLIFE, INC.': ['FINANCE', 'LIFE INSURANCE'],
#  'MFA FINANCIAL, INC.': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'MID-AMERICA APARTMENT COMMUNITIES, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'MOLSON COORS BREWING  COMPANY': ['CONSUMER NON-DURABLES',
#   'BEVERAGES (PRODUCTION/DISTRIBUTION)'],
#  'MONMOUTH REAL ESTATE INVESTMENT CORPORATION': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'MORGAN STANLEY': ['FINANCE', 'INVESTMENT BANKERS/BROKERS/SERVICE'],
#  'MOSAIC ACQUISITION CORP.': ['FINANCE', 'BUSINESS SERVICES'],
#  'NATIONAL RETAIL PROPERTIES': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'NATIONAL STORAGE AFFILIATES TRUST': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'NAVIOS MARITIME HOLDINGS INC.': ['TRANSPORTATION', 'MARINE TRANSPORTATION'],
#  'NEW YORK COMMUNITY BANCORP, INC.': ['FINANCE', 'BANKS'],
#  'NEXTERA ENERGY, INC.': ['PUBLIC UTILITIES', 'ELECTRIC UTILITIES: CENTRAL'],
#  'NGL ENERGY PARTNERS LP': ['ENERGY', 'OIL REFINING/MARKETING'],
#  'NRG YIELD, INC.': ['PUBLIC UTILITIES', 'ELECTRIC UTILITIES: CENTRAL'],
#  'NUSTAR ENERGY L.P.': ['ENERGY', 'NATURAL GAS DISTRIBUTION'],
#  'OFG BANCORP': ['FINANCE', 'MAJOR BANKS'],
#  'ONE MADISON CORPORATION': ['FINANCE', 'BUSINESS SERVICES'],
#  'PEBBLEBROOK HOTEL TRUST': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'PENNSYLVANIA REAL ESTATE INVESTMENT TRUST': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'PENNYMAC MORTGAGE INVESTMENT TRUST': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'PETROLEO BRASILEIRO S.A.- PETROBRAS': ['ENERGY', 'OIL & GAS PRODUCTION'],
#  'PITNEY BOWES INC.': ['MISCELLANEOUS', 'OFFICE EQUIPMENT/SUPPLIES/SERVICES'],
#  'PNC FINANCIAL SERVICES GROUP, INC. (THE)': ['FINANCE', 'MAJOR BANKS'],
#  'PRUDENTIAL PUBLIC LIMITED COMPANY': ['FINANCE', 'LIFE INSURANCE'],
#  'PS BUSINESS PARKS, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'PUBLIC STORAGE': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'QTS REALTY TRUST, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'RAIT FINANCIAL TRUST': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'RAMCO-GERSHENSON PROPERTIES TRUST': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'RAYONIER ADVANCED MATERIALS INC.': ['BASIC INDUSTRIES', 'MAJOR CHEMICALS'],
#  'REGALWOOD GLOBAL ENERGY LTD.': ['FINANCE', 'BUSINESS SERVICES'],
#  'REGIONS FINANCIAL CORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'RENAISSANCERE HOLDINGS LTD.': ['FINANCE', 'PROPERTY-CASUALTY INSURERS'],
#  'RESOURCE CAPITAL CORP.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'REXFORD INDUSTRIAL REALTY, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'REXNORD CORPORATION': ['TECHNOLOGY', 'INDUSTRIAL MACHINERY/COMPONENTS'],
#  'RLJ LODGING TRUST': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'ROYAL BANK OF CANADA': ['FINANCE', 'COMMERCIAL BANKS'],
#  'ROYAL BANK SCOTLAND PLC (THE)': ['FINANCE', 'COMMERCIAL BANKS'],
#  'SAFE BULKERS, INC': ['TRANSPORTATION', 'MARINE TRANSPORTATION'],
#  'SAUL CENTERS, INC.': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'SEASPAN CORPORATION': ['TRANSPORTATION', 'MARINE TRANSPORTATION'],
#  'SERITAGE GROWTH PROPERTIES': ['FINANCE', 'REAL ESTATE'],
#  'SIMON PROPERTY GROUP, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'SL GREEN REALTY CORPORATION': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'SOCIAL CAPITAL HEDOSOPHIA HOLDINGS CORP.': ['FINANCE', 'BUSINESS SERVICES'],
#  'SPIRIT REALTY CAPITAL, INC.': ['CONSUMER SERVICES', 'BUILDING OPERATORS'],
#  'STAG INDUSTRIAL, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'STATE STREET CORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'STEEL PARTNERS HOLDINGS LP': ['CAPITAL GOODS', 'INDUSTRIAL SPECIALTIES'],
#  'SUMMIT HOTEL PROPERTIES, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'SUNSTONE HOTEL INVESTORS, INC.': ['CONSUMER SERVICES', 'HOTELS/RESORTS'],
#  'SUNTRUST BANKS, INC.': ['FINANCE', 'MAJOR BANKS'],
#  'SYNOVUS FINANCIAL CORP.': ['FINANCE', 'MAJOR BANKS'],
#  'SYNTHETIC FIXED-INCOME SECURITIES, INC.': ['FINANCE',
#   'FINANCE: CONSUMER SERVICES'],
#  'TAUBMAN CENTERS, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'TCF FINANCIAL CORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'TEEKAY LNG PARTNERS L.P.': ['CONSUMER SERVICES', 'MARINE TRANSPORTATION'],
#  'TEEKAY OFFSHORE PARTNERS L.P.': ['CONSUMER SERVICES',
#   'MARINE TRANSPORTATION'],
#  'TELECOM ITALIA S.P.A.': ['CONSUMER SERVICES',
#   'TELECOMMUNICATIONS EQUIPMENT'],
#  'THE CHARLES SCHWAB CORPORATION': ['FINANCE',
#   'INVESTMENT BANKERS/BROKERS/SERVICE'],
#  'TIDEWATER INC.': ['CONSUMER SERVICES', 'MARINE TRANSPORTATION'],
#  'TORCHMARK CORPORATION': ['FINANCE', 'LIFE INSURANCE'],
#  'TPG PACE ENERGY HOLDINGS CORP.': ['FINANCE', 'BUSINESS SERVICES'],
#  'TPG PACE HOLDINGS CORP.': ['FINANCE', 'BUSINESS SERVICES'],
#  'TRI CONTINENTAL CORPORATION': ['CONSUMER SERVICES', 'MISCELLANEOUS'],
#  'TSAKOS ENERGY NAVIGATION LTD': ['TRANSPORTATION', 'MARINE TRANSPORTATION'],
#  'TWO HARBORS INVESTMENTS CORP': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'U.S. BANCORP': ['FINANCE', 'MAJOR BANKS'],
#  'UMH PROPERTIES, INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'UNION ACQUISITION CORP.': ['FINANCE', 'BUSINESS SERVICES'],
#  'URSTADT BIDDLE PROPERTIES INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'VALIDUS HOLDINGS, LTD.': ['FINANCE', 'PROPERTY-CASUALTY INSURERS'],
#  'VALLEY NATIONAL BANCORP': ['FINANCE', 'MAJOR BANKS'],
#  'VEREIT INC.': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS'],
#  'VISTRA ENERGY CORP.': ['PUBLIC UTILITIES', 'ELECTRIC UTILITIES: CENTRAL'],
#  'VORNADO REALTY TRUST': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'W.R. BERKLEY CORPORATION': ['FINANCE', 'PROPERTY-CASUALTY INSURERS'],
#  'WASHINGTON PRIME GROUP INC.': ['CONSUMER SERVICES',
#   'REAL ESTATE INVESTMENT TRUSTS'],
#  'WATSCO, INC.': ['CONSUMER DURABLES', 'INDUSTRIAL MACHINERY/COMPONENTS'],
#  'WEBSTER FINANCIAL CORPORATION': ['FINANCE', 'MAJOR BANKS'],
#  'WELLS FARGO & COMPANY': ['FINANCE', 'MAJOR BANKS'],
#  'WELLTOWER INC.': ['CONSUMER SERVICES', 'REAL ESTATE INVESTMENT TRUSTS']}

# %%
diz['APARTMENT INVESTMENT AND MANAGEMENT COMPANY'][0]
# Out:
# 'CONSUMER SERVICES'

# %%
diz['APARTMENT INVESTMENT AND MANAGEMENT COMPANY'][1]
# Out:
# 'REAL ESTATE INVESTMENT TRUSTS'

# %%
for i in diz.keys():
    print(i)
print(len(diz.keys()))
# Out:
# AMTRUST FINANCIAL SERVICES, INC.
# BARCLAYS PLC
# M I ACQUISITIONS, INC.
# MAIDEN HOLDINGS, LTD.
# ZIONS BANCORPORATION
# AEGON NV
# ALEXANDRIA REAL ESTATE EQUITIES, INC.
# ALLSTATE CORPORATION (THE)
# ALLY FINANCIAL INC.
# AMERICAN HOMES 4 RENT
# AMERICAN INTERNATIONAL GROUP, INC.
# ANNALY CAPITAL MANAGEMENT INC
# ANWORTH MORTGAGE ASSET  CORPORATION
# APARTMENT INVESTMENT AND MANAGEMENT COMPANY
# APOLLO COMMERCIAL REAL ESTATE FINANCE
# APOLLO GLOBAL MANAGEMENT, LLC
# ARBOR REALTY TRUST
# ARES MANAGEMENT L.P.
# ARLINGTON ASSET INVESTMENT CORP
# ARMOUR RESIDENTIAL REIT, INC.
# ASHFORD HOSPITALITY TRUST INC
# ASPEN INSURANCE HOLDINGS LIMITED
# ASSOCIATED BANC-CORP
# ASSURED GUARANTY LTD.
# AXIS CAPITAL HOLDINGS LIMITED
# BANC OF CALIFORNIA, INC.
# BANCO SANTANDER, S.A.
# BANK OF AMERICA CORPORATION
# BANK OF NEW YORK MELLON CORPORATION (THE)
# BB&T CORPORATION
# BELDEN INC
# BIGLARI HOLDINGS INC.
# BIO-RAD LABORATORIES, INC.
# BOSTON PROPERTIES, INC.
# BRAEMAR HOTELS & RESORTS INC.
# CAI INTERNATIONAL, INC.
# CAPITAL ONE FINANCIAL CORPORATION
# CAPITOL INVESTMENT CORP. IV
# CAPSTEAD MORTGAGE CORPORATION
# CBL & ASSOCIATES PROPERTIES, INC.
# CEDAR REALTY TRUST, INC.
# CENTRAIS ELECTRICAS BRASILEIRAS S.A.- ELETROBRAS
# CHERRY HILL MORTGAGE INVESTMENT CORPORATION
# CHESAPEAKE ENERGY CORPORATION
# CHIMERA INVESTMENT CORPORATION
# CINCINNATI BELL INC
# CITIGROUP INC.
# CITY OFFICE REIT, INC.
# COLONY NORTHSTAR, INC.
# COMERICA INCORPORATED
# COMP EN DE MN CEMIG ADS
# COMPASS DIVERSIFIED HOLDINGS
# CONSTELLATION BRANDS INC
# KEYCORP
# CORENERGY INFRASTRUCTURE TRUST, INC.
# COSTAMARE INC.
# CROWN CASTLE INTERNATIONAL CORPORATION
# CULLEN/FROST BANKERS, INC.
# CUSTOMERS BANCORP, INC
# CYS INVESTMENTS, INC.
# DDR CORP.
# DIANA SHIPPING INC.
# DIGITAL REALTY TRUST, INC.
# DRIVE SHACK INC.
# DYNAGAS LNG PARTNERS LP
# DYNEX CAPITAL, INC.
# EASTMAN KODAK COMPANY
# EATON VANCE CORPORATION
# ENERGY TRANSFER PARTNERS, L.P.
# EPR PROPERTIES
# EQUITY COMMONWEALTH
# F.N.B. CORPORATION
# FARMLAND PARTNERS INC.
# FEDERAL AGRICULTURAL MORTGAGE CORPORATION
# FEDERAL REALTY INVESTMENT TRUST
# FGL HOLDINGS
# FIRST HORIZON NATIONAL CORPORATION
# FIVE OAKS INVESTMENT CORP.
# GASLOG LP.
# GASLOG PARTNERS LP
# GENERAL MOTORS COMPANY
# GENIE ENERGY LTD.
# GIGCAPITAL, INC.
# GLOBAL MEDICAL REIT INC.
# GLOBAL NET LEASE, INC.
# GLOBAL SHIP LEASE, INC.
# GOLDMAN SACHS GROUP, INC. (THE)
# GRAY TELEVISION, INC.
# HALCON RESOURCES CORPORATION
# HARTFORD FINANCIAL SERVICES GROUP, INC. (THE)
# HAVERTY FURNITURE COMPANIES, INC.
# HAWAIIAN ELECTRIC INDUSTRIES, INC.
# HEICO CORPORATION
# HERSHA HOSPITALITY TRUST
# HESS CORPORATION
# HOEGH LNG PARTNERS LP
# HSBC HOLDINGS PLC
# HUDBAY MINERALS INC.
# INNOVATIVE INDUSTRIAL PROPERTIES, INC.
# INVESCO MORTGAGE CAPITAL INC
# INVESTORS REAL ESTATE TRUST
# ISTAR FINANCIAL INC.
# J P MORGAN CHASE & CO
# JERNIGAN CAPITAL, INC.
# JUST ENERGY GROUP, INC.
# KIMCO REALTY CORPORATION
# KINDER MORGAN, INC.
# KKR & CO. L.P.
# LASALLE HOTEL PROPERTIES
# LEGACY ACQUISITION CORP.
# LEO HOLDINGS CORP.
# LINCOLN NATIONAL CORPORATION
# M&T BANK CORPORATION
# MECHEL PAO
# METLIFE, INC.
# MFA FINANCIAL, INC.
# MID-AMERICA APARTMENT COMMUNITIES, INC.
# MOLSON COORS BREWING  COMPANY
# MONMOUTH REAL ESTATE INVESTMENT CORPORATION
# MORGAN STANLEY
# MOSAIC ACQUISITION CORP.
# NATIONAL RETAIL PROPERTIES
# NATIONAL STORAGE AFFILIATES TRUST
# NAVIOS MARITIME HOLDINGS INC.
# NEW YORK COMMUNITY BANCORP, INC.
# NEXTERA ENERGY, INC.
# NGL ENERGY PARTNERS LP
# NRG YIELD, INC.
# NUSTAR ENERGY L.P.
# OFG BANCORP
# ONE MADISON CORPORATION
# PEBBLEBROOK HOTEL TRUST
# PENNSYLVANIA REAL ESTATE INVESTMENT TRUST
# PENNYMAC MORTGAGE INVESTMENT TRUST
# PETROLEO BRASILEIRO S.A.- PETROBRAS
# PITNEY BOWES INC.
# PNC FINANCIAL SERVICES GROUP, INC. (THE)
# PRUDENTIAL PUBLIC LIMITED COMPANY
# PS BUSINESS PARKS, INC.
# PUBLIC STORAGE
# QTS REALTY TRUST, INC.
# RAIT FINANCIAL TRUST
# RAMCO-GERSHENSON PROPERTIES TRUST
# RAYONIER ADVANCED MATERIALS INC.
# REGALWOOD GLOBAL ENERGY LTD.
# REGIONS FINANCIAL CORPORATION
# RENAISSANCERE HOLDINGS LTD.
# RESOURCE CAPITAL CORP.
# REXFORD INDUSTRIAL REALTY, INC.
# REXNORD CORPORATION
# RLJ LODGING TRUST
# ROYAL BANK OF CANADA
# ROYAL BANK SCOTLAND PLC (THE)
# SAFE BULKERS, INC
# SAUL CENTERS, INC.
# SEASPAN CORPORATION
# SERITAGE GROWTH PROPERTIES
# SIMON PROPERTY GROUP, INC.
# SL GREEN REALTY CORPORATION
# SOCIAL CAPITAL HEDOSOPHIA HOLDINGS CORP.
# SPIRIT REALTY CAPITAL, INC.
# STAG INDUSTRIAL, INC.
# STATE STREET CORPORATION
# STEEL PARTNERS HOLDINGS LP
# SUMMIT HOTEL PROPERTIES, INC.
# SUNSTONE HOTEL INVESTORS, INC.
# SUNTRUST BANKS, INC.
# SYNOVUS FINANCIAL CORP.
# SYNTHETIC FIXED-INCOME SECURITIES, INC.
# TAUBMAN CENTERS, INC.
# TCF FINANCIAL CORPORATION
# TEEKAY LNG PARTNERS L.P.
# TEEKAY OFFSHORE PARTNERS L.P.
# TELECOM ITALIA S.P.A.
# THE CHARLES SCHWAB CORPORATION
# TIDEWATER INC.
# TORCHMARK CORPORATION
# TPG PACE ENERGY HOLDINGS CORP.
# TPG PACE HOLDINGS CORP.
# TRI CONTINENTAL CORPORATION
# TSAKOS ENERGY NAVIGATION LTD
# TWO HARBORS INVESTMENTS CORP
# U.S. BANCORP
# UMH PROPERTIES, INC.
# UNION ACQUISITION CORP.
# URSTADT BIDDLE PROPERTIES INC.
# VALIDUS HOLDINGS, LTD.
# VALLEY NATIONAL BANCORP
# VEREIT INC.
# VISTRA ENERGY CORP.
# VORNADO REALTY TRUST
# W.R. BERKLEY CORPORATION
# WASHINGTON PRIME GROUP INC.
# WATSCO, INC.
# WEBSTER FINANCIAL CORPORATION
# WELLS FARGO & COMPANY
# WELLTOWER INC.
# 197

# %%
# per tutte le chiavi della lista, quindi per tutte le aziende che si sono scordate qualcosa
for key in diz.keys():
    # sostituisco nel dataset tutti i valori in sector e industry con i valori corretti
    # sostituisco anche quelli che già ci sono, ma non fa niente
    dataStocks.loc[dataStocks.name == key, 'sector'] = diz[key][0]
    dataStocks.loc[dataStocks.name == key, 'industry'] = diz[key][1]

# %%
dataStocks[dataStocks.name == 'GASLOG LP.']
# Out:
#       ticker exchange        name             sector               industry
# 4561    GLOG     NYSE  GASLOG LP.  CONSUMER SERVICES  MARINE TRANSPORTATION
# 4562  GLOG^A     NYSE  GASLOG LP.  CONSUMER SERVICES  MARINE TRANSPORTATION

# %%
dataStocks.isnull().sum()
# Out:
# ticker         0
# exchange       0
# name           0
# sector      1018
# industry    1018
# dtype: int64

# %%
dataStocks.nunique()
# Out:
# ticker      6460
# exchange       2
# name        5462
# sector        13
# industry     136
# dtype: int64

# %%
# 6460 - 1018 = 5442
dataStocks.dropna(axis=0, inplace=True)

# %%
dataStocks.nunique()
# Out:
# ticker      5442
# exchange       2
# name        4551
# sector        13
# industry     136
# dtype: int64

# %%
dataStocks.isnull().sum()
# Out:
# ticker      0
# exchange    0
# name        0
# sector      0
# industry    0
# dtype: int64

# %%
dataStocks['name'] = dataStocks['name'].str.replace(',', '')

# %%
dataStocks.to_csv('dataset/historical_stocks_clean.csv', index = False)

# %%
dataClean = pd.read_csv("dataset/historical_stocks_clean.csv")

# %%
dataClean
# Out:
#      ticker exchange                                   name  \
# 0       PIH   NASDAQ  1347 PROPERTY INSURANCE HOLDINGS INC.
# 1     PIHPP   NASDAQ  1347 PROPERTY INSURANCE HOLDINGS INC.
# 2      TURN   NASDAQ               180 DEGREE CAPITAL CORP.
# 3      FLWS   NASDAQ                 1-800 FLOWERS.COM INC.
# 4      FCCY   NASDAQ          1ST CONSTITUTION BANCORP (NJ)
# ...     ...      ...                                    ...
# 5437   ZOES     NYSE                 ZOE&#39;S KITCHEN INC.
# 5438    ZTS     NYSE                            ZOETIS INC.
# 5439    ZTO     NYSE              ZTO EXPRESS (CAYMAN) INC.
# 5440    ZUO     NYSE                             ZUORA INC.
# 5441   ZYME     NYSE                         ZYMEWORKS INC.
#
#                  sector                                 industry
# 0               FINANCE               PROPERTY-CASUALTY INSURERS
# 1               FINANCE               PROPERTY-CASUALTY INSURERS
# 2               FINANCE               FINANCE/INVESTORS SERVICES
# 3     CONSUMER SERVICES                   OTHER SPECIALTY STORES
# 4               FINANCE                     SAVINGS INSTITUTIONS
# ...                 ...                                      ...
# 5437  CONSUMER SERVICES                              RESTAURANTS
# 5438        HEALTH CARE                    MAJOR PHARMACEUTICALS
# 5439     TRANSPORTATION        TRUCKING FREIGHT/COURIER SERVICES
# 5440         TECHNOLOGY  COMPUTER SOFTWARE: PREPACKAGED SOFTWARE
# 5441        HEALTH CARE                    MAJOR PHARMACEUTICALS
#
# [5442 rows x 5 columns]
