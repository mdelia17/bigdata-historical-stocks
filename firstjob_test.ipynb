# %%
import pandas as pd
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv("dataset/historical_stock_prices.csv")

# %%
df = df[:100]
df
# Out:
#    ticker       open      close  adj_close        low       high    volume  \
# 0     AHH  11.500000  11.580000   8.493155  11.250000  11.680000   4633900
# 1     AHH  11.660000  11.550000   8.471151  11.500000  11.660000    275800
# 2     AHH  11.550000  11.600000   8.507822  11.500000  11.600000    277100
# 3     AHH  11.630000  11.650000   8.544494  11.550000  11.650000    147400
# 4     AHH  11.600000  11.530000   8.456484  11.500000  11.600000    184100
# 5     AHH  11.600000  11.600000   8.507822  11.540000  11.600000     76800
# 6     AHH  11.620000  11.740000   8.610501  11.540000  11.740000    170300
# 7     AHH  11.700000  11.760000   8.625172  11.700000  11.850000    305400
# 8     AHH  11.760000  11.730000   8.603169  11.630000  11.830000     46800
# 9     AHH  11.760000  11.830000   8.676512  11.610000  11.840000     77000
# 10    AHH  11.840000  11.750000   8.617840  11.680000  11.840000     90200
# ...

# %%
df.to_csv("dataset/firstjob_test.csv", index=False, header=False)
